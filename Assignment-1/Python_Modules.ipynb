# %% [markdown]
# # Numpy Implementation

# %%
import numpy as np
# Create a 2D Numpy array of size 1x3 with elements of your choice
arr1= np.array([[1,3,4]])

# Create a Numpy array of length 50 with zeroes as its elements
arr2= np.zeros(50)

#Create a Numpy array of length 3x2 with elements of your choice
arr3= np.array([[1,2], [4,5], [7,6]])

#Multiply arr1 and arr3 using Numpy functions
arr4= np.matmul(arr1, arr3)

#Change 5th element of arr2 to a different number
arr2[4] = 5

if np.shape(arr4)==(1,2) and arr2[4]!=0:
  print("Passed")
else:
  print("Fail")
# Out:
# Passed

# %%
import numpy as np

#Task: Perform the dot product of I and 9I+1 using numpy, here I is referred to as an 3x3 Identity matrix.
I = np.identity(3)
result = np.dot(I, 9*I + 1)
print(result)
# Out:
# [[10.  1.  1.]
#  [ 1. 10.  1.]
#  [ 1.  1. 10.]]

# %% [markdown]
# # Pandas Implementation

# %%
import pandas as pd

## Create a DataFrame from a dictionary
data = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, 30, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}
df = pd.DataFrame(data)
#Display the first 2 rows of the data frame
print(df[0:2])
#Print the age column
print(df['Age'])
#Filter rows where age is greater than 26
filtered_df = df[df['Age']>26]
#Add a new column 'Country' with the value 'India' for all rows
df['Country'] = 'India'

data1 = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, None, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}

df2= pd.DataFrame(data1)

# Fill missing values in the 'Age' column with the mean age
df2.loc[1, 'Age'] = df2['Age'].mean()
# Out:
#      Name  Age       City
# 0  Ramesh   25  Bangalore
# 1  Mahesh   30     Mumbai
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %% [markdown]
# # Matplotlib Implementation

# %%
import matplotlib.pyplot as plt
#numpy module
import numpy as np



xpoints=np.array([1,2,3,4])
ypoints=np.array([2,4,6,8])

#Plot these points without drawing a line
plt.plot(xpoints, ypoints, 'o')
plt.show()
#Plotting with marker: Plot these points with a marker(Star marker)
plt.plot(xpoints, ypoints, '*')
plt.show()
#Using fmt format, add circular marker,red color and Dashed line
plt.plot(xpoints, ypoints, 'o--r')
#Add xlabel,ylabel and title for the plot.
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Plot of line : y = 2x')
plt.show()
#Create a scatter plot for xpoints and ypoints
plt.scatter(xpoints, ypoints)
plt.show()
#Set color to the scatter plot. Blue,Green,Red and yellow color for each point respectively
colors = np.array(['blue', 'green', 'red', 'yellow'])
plt.scatter(xpoints, ypoints, c=colors)
plt.show()

# %% [markdown]
# # Miscellaneous Modules Implementation

# %%
import random
import numpy as np

#Set the seed of random to 20
np.random.seed(20)
arr1=np.array([1,24,31,45,73,81,94,25])

#Using the random module pick 4 different random numbers from arr1 and return their sum.
arr2 = random.choices(arr1, k=4)
sum_arr2 = np.sum(arr2)
print(f"Sum of all the elements in array : {arr2} is {sum_arr2}")
# Out:
# Sum of all the elements in array : [45, 81, 31, 1] is 158
